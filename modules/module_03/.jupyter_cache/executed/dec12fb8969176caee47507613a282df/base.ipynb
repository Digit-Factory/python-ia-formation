# %%
# imports
import os
import sys
import types
import json
import base64

# figure size/format
fig_width = 5.5
fig_height = 3.5
fig_format = 'pdf'
fig_dpi = 300
interactivity = ''
is_shiny = False
is_dashboard = False
plotly_connected = True

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = "figure"

  # IPython 7.14 deprecated set_matplotlib_formats from IPython
  try:
    from matplotlib_inline.backend_inline import set_matplotlib_formats
  except ImportError:
    # Fall back to deprecated location for older IPython versions
    from IPython.display import set_matplotlib_formats
    
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  if plotly_connected:
    pio.renderers.default = "notebook_connected"
  else:
    pio.renderers.default = "notebook"
  for template in pio.templates.keys():
    pio.templates[template].layout.margin = dict(t=30,r=0,b=0,l=0)
except Exception:
  pass

# disable itables paging for dashboards
if is_dashboard:
  try:
    from itables import options
    options.dom = 'fiBrtlp'
    options.maxBytes = 1024 * 1024
    options.language = dict(info = "Showing _TOTAL_ entries")
    options.classes = "display nowrap compact"
    options.paging = False
    options.searching = True
    options.ordering = True
    options.info = True
    options.lengthChange = False
    options.autoWidth = False
    options.responsive = True
    options.keys = True
    options.buttons = []
  except Exception:
    pass
  
  try:
    import altair as alt
    # By default, dashboards will have container sized
    # vega visualizations which allows them to flow reasonably
    theme_sentinel = '_quarto-dashboard-internal'
    def make_theme(name):
        nonTheme = alt.themes._plugins[name]    
        def patch_theme(*args, **kwargs):
            existingTheme = nonTheme()
            if 'height' not in existingTheme:
              existingTheme['height'] = 'container'
            if 'width' not in existingTheme:
              existingTheme['width'] = 'container'

            if 'config' not in existingTheme:
              existingTheme['config'] = dict()
            
            # Configure the default font sizes
            title_font_size = 15
            header_font_size = 13
            axis_font_size = 12
            legend_font_size = 12
            mark_font_size = 12
            tooltip = False

            config = existingTheme['config']

            # The Axis
            if 'axis' not in config:
              config['axis'] = dict()
            axis = config['axis']
            if 'labelFontSize' not in axis:
              axis['labelFontSize'] = axis_font_size
            if 'titleFontSize' not in axis:
              axis['titleFontSize'] = axis_font_size  

            # The legend
            if 'legend' not in config:
              config['legend'] = dict()
            legend = config['legend']
            if 'labelFontSize' not in legend:
              legend['labelFontSize'] = legend_font_size
            if 'titleFontSize' not in legend:
              legend['titleFontSize'] = legend_font_size  

            # The header
            if 'header' not in config:
              config['header'] = dict()
            header = config['header']
            if 'labelFontSize' not in header:
              header['labelFontSize'] = header_font_size
            if 'titleFontSize' not in header:
              header['titleFontSize'] = header_font_size    

            # Title
            if 'title' not in config:
              config['title'] = dict()
            title = config['title']
            if 'fontSize' not in title:
              title['fontSize'] = title_font_size

            # Marks
            if 'mark' not in config:
              config['mark'] = dict()
            mark = config['mark']
            if 'fontSize' not in mark:
              mark['fontSize'] = mark_font_size

            # Mark tooltips
            if tooltip and 'tooltip' not in mark:
              mark['tooltip'] = dict(content="encoding")

            return existingTheme
            
        return patch_theme

    # We can only do this once per session
    if theme_sentinel not in alt.themes.names():
      for name in alt.themes.names():
        alt.themes.register(name, make_theme(name))
      
      # register a sentinel theme so we only do this once
      alt.themes.register(theme_sentinel, make_theme('default'))
      alt.themes.enable('default')

  except Exception:
    pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass

# interactivity
if interactivity:
  from IPython.core.interactiveshell import InteractiveShell
  InteractiveShell.ast_node_interactivity = interactivity

# NOTE: the kernel_deps code is repeated in the cleanup.py file
# (we can't easily share this code b/c of the way it is run).
# If you edit this code also edit the same code in cleanup.py!

# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
run_path = 'QzpcVXNlcnNcbG9pY2hcRG9jdW1lbnRzXFdvcmtcR2l0aHViXHF1YXJ0b1xweXRob25faWFfcXVhcnRvXG1vZHVsZXNcbW9kdWxlXzAz'
if run_path:
  # hex-decode the path
  run_path = base64.b64decode(run_path.encode("utf-8")).decode("utf-8")
  os.chdir(run_path)

# reset state
# %reset

# shiny
# Checking for shiny by using False directly because we're after the %reset. We don't want
# to set a variable that stays in global scope.
if False:
  try:
    import htmltools as _htmltools
    import ast as _ast

    _htmltools.html_dependency_render_mode = "json"

    # This decorator will be added to all function definitions
    def _display_if_has_repr_html(x):
      try:
        # IPython 7.14 preferred import
        from IPython.display import display, HTML
      except:
        from IPython.core.display import display, HTML

      if hasattr(x, '_repr_html_'):
        display(HTML(x._repr_html_()))
      return x

    # ideally we would undo the call to ast_transformers.append
    # at the end of this block whenver an error occurs, we do 
    # this for now as it will only be a problem if the user 
    # switches from shiny to not-shiny mode (and even then likely
    # won't matter)
    import builtins
    builtins._display_if_has_repr_html = _display_if_has_repr_html

    class _FunctionDefReprHtml(_ast.NodeTransformer):
      def visit_FunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

      def visit_AsyncFunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

    ip = get_ipython()
    ip.ast_transformers.append(_FunctionDefReprHtml())

  except:
    pass

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v

  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
globals()["__spec__"] = None
# Out:
# {"C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\_bootstrap.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\_bootstrap_external.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\zipimport.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\codecs.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\aliases.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\__init__.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\utf_8.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\cp1252.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\abc.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\io.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\stat.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\_collections_abc.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\genericpath.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\ntpath.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\os.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\_sitebuiltins.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\utf_8_sig.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\_distutils_hack\\__init__.py": 1776674316.670877, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\warnings.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\__init__.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\machinery.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\_abc.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\types.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\util.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\runpy.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\posixpath.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\operator.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\keyword.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\reprlib.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\collections\\__init__.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\functools.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\enum.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\_constants.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\_parser.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\_casefix.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\_compiler.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\copyreg.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\__init__.py": 1727748220.0, "C:\\Users\\loich\\AppData\\Local\\Programs\\ ...

# %%
#| label: setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 4)
pd.set_option('display.max_columns', 20)

print("✅ Environnement prêt")
# Out:
# ✅ Environnement prêt

# %%
# Créer un petit dataset pédagogique avec tous les types de variables
data = {
    # Quantitatives continues
    "taille_m": [1.72, 1.68, 1.85, 1.65, 1.90, 1.78, 1.60, 1.82],
    "poids_kg": [68.5, 55.2, 89.0, 52.1, 95.3, 71.8, 48.5, 80.0],
    
    # Quantitative discrète
    "nb_enfants": [2, 0, 3, 1, 2, 0, 0, 1],
    
    # "Codes numériques" (PIÈGE : ce sont des qualitatives nominales)
    "code_postal": [75001, 13000, 69000, 44000, 33000, 75015, 69003, 13008],
    "id_client": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008],
    
    # Qualitatives nominales
    "ville": ["Paris", "Marseille", "Lyon", "Nantes", "Bordeaux", "Paris", "Lyon", "Marseille"],
    "genre": ["M", "F", "M", "F", "M", "F", "F", "M"],
    
    # Qualitatives ordinales
    "satisfaction": ["Bon", "Moyen", "Excellent", "Mauvais", "Bon", "Excellent", "Bon", "Moyen"],
    "niveau_etudes": ["Master", "Licence", "Doctorat", "Bac", "Master", "Doctorat", "Licence", "Bac"],
    
    # Textuelle
    "commentaire": [
        "Super expérience, très satisfait !",
        "Livraison trop longue",
        "Produit parfait, rien à redire",
        "Article cassé à la réception",
        "RAS",
        "Excellente qualité prix",
        "Bof, j'attendais mieux",
        "Parfait, je recommande"
    ],
    
    # Temporelle
    "date_inscription": pd.to_datetime([
        "2022-01-15", "2021-06-22", "2023-03-08", "2020-11-30",
        "2023-07-04", "2022-09-12", "2021-12-25", "2023-05-01"
    ])
}

df = pd.DataFrame(data)
df
# Out:
#    taille_m  poids_kg  nb_enfants  code_postal  id_client      ville genre  \
# 0      1.72      68.5           2        75001       1001      Paris     M
# 1      1.68      55.2           0        13000       1002  Marseille     F
# 2      1.85      89.0           3        69000       1003       Lyon     M
# 3      1.65      52.1           1        44000       1004     Nantes     F
# 4      1.90      95.3           2        33000       1005   Bordeaux     M
# 5      1.78      71.8           0        75015       1006      Paris     F
# 6      1.60      48.5           0        69003       1007       Lyon     F
# 7      1.82      80.0           1        13008       1008  Marseille     M
#
#   satisfaction niveau_etudes                         commentaire  \
# 0          Bon        Master  Super expérience, très satisfait !
# 1        Moyen       Licence               Livraison trop longue
# 2    Excellent      Doctorat      Produit parfait, rien à redire
# 3      Mauvais           Bac        Article cassé à la réception
# 4          Bon        Master                                 RAS
# 5    Excellent      Doctorat             Excellente qualité prix
# 6          Bon       Licence              Bof, j'attendais mieux
# 7        Moyen           Bac              Parfait, je recommande
#
#   date_inscription
# 0       2022-01-15
# 1       2021-06-22
# 2       2023-03-08
# 3       2020-11-30
# 4       2023-07-04
# 5       2022-09-12
# 6       2021-12-25
# 7       2023-05-01

# %%
df.dtypes
# Out:
# taille_m                   float64
# poids_kg                   float64
# nb_enfants                   int64
# code_postal                  int64
# id_client                    int64
# ville                          str
# genre                          str
# satisfaction                   str
# niveau_etudes                  str
# commentaire                    str
# date_inscription    datetime64[us]
# dtype: object

# %%
df.describe()
# Out:
#        taille_m   poids_kg  nb_enfants   code_postal   id_client  \
# count  8.000000   8.000000    8.000000      8.000000     8.00000
# mean   1.750000  70.050000    1.125000  48878.375000  1004.50000
# min    1.600000  48.500000    0.000000  13000.000000  1001.00000
# 25%    1.672500  54.425000    0.000000  28002.000000  1002.75000
# 50%    1.750000  70.150000    1.000000  56500.000000  1004.50000
# 75%    1.827500  82.250000    2.000000  70502.500000  1006.25000
# max    1.900000  95.300000    3.000000  75015.000000  1008.00000
# std    0.104608  17.354538    1.125992  26793.543886     2.44949
#
#           date_inscription
# count                    8
# mean   2022-05-23 00:00:00
# min    2020-11-30 00:00:00
# 25%    2021-11-08 12:00:00
# 50%    2022-05-15 00:00:00
# 75%    2023-03-21 12:00:00
# max    2023-07-04 00:00:00
# std                    NaN

# %%
# Convertir en string (simple)
df["code_postal"] = df["code_postal"].astype(str)
df["id_client"] = df["id_client"].astype(str)

print(df.dtypes)
# Out:
# taille_m                   float64
# poids_kg                   float64
# nb_enfants                   int64
# code_postal                    str
# id_client                      str
# ville                          str
# genre                          str
# satisfaction                   str
# niveau_etudes                  str
# commentaire                    str
# date_inscription    datetime64[us]
# dtype: object

# %%
df.describe()
# Out:
#        taille_m   poids_kg  nb_enfants     date_inscription
# count  8.000000   8.000000    8.000000                    8
# mean   1.750000  70.050000    1.125000  2022-05-23 00:00:00
# min    1.600000  48.500000    0.000000  2020-11-30 00:00:00
# 25%    1.672500  54.425000    0.000000  2021-11-08 12:00:00
# 50%    1.750000  70.150000    1.000000  2022-05-15 00:00:00
# 75%    1.827500  82.250000    2.000000  2023-03-21 12:00:00
# max    1.900000  95.300000    3.000000  2023-07-04 00:00:00
# std    0.104608  17.354538    1.125992                  NaN

# %%
df["ville"] = df["ville"].astype("category")
df["genre"] = df["genre"].astype("category")

print(df[["ville", "genre"]].dtypes)
# Out:
# ville    category
# genre    category
# dtype: object

# %%
# Gain de mémoire (surtout sur gros datasets)
memoire_object = df["ville"].astype("object").memory_usage(deep=True)
memoire_category = df["ville"].memory_usage(deep=True)
print(f"Mémoire avec object   : {memoire_object} octets")
print(f"Mémoire avec category : {memoire_category} octets")
# Out:
# Mémoire avec object   : 574 octets
# Mémoire avec category : 417 octets

# %%
from pandas.api.types import CategoricalDtype

# Définir l'ordre
ordre_satisfaction = CategoricalDtype(
    categories=["Mauvais", "Moyen", "Bon", "Excellent"],
    ordered=True
)
df["satisfaction"] = df["satisfaction"].astype(ordre_satisfaction)

print(f"Dtype : {df['satisfaction'].dtype}")
print(f"Ordre : {df['satisfaction'].cat.categories.tolist()}")
# Out:
# Dtype : category
# Ordre : ['Mauvais', 'Moyen', 'Bon', 'Excellent']

# %%
# Qui a eu au moins "Bon" ?
df[df["satisfaction"] >= "Bon"][["ville", "satisfaction"]]
# Out:
#       ville satisfaction
# 0     Paris          Bon
# 2      Lyon    Excellent
# 4  Bordeaux          Bon
# 5     Paris    Excellent
# 6      Lyon          Bon

# %%
#| eval: false
# TODO: Exercice 1 — Réponds dans des commentaires ou markdown

# %%
# Exemple : poids
print(df["poids_kg"].describe())
# Out:
# count     8.000000
# mean     70.050000
# std      17.354538
# min      48.500000
# 25%      54.425000
# 50%      70.150000
# 75%      82.250000
# max      95.300000
# Name: poids_kg, dtype: float64

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Histogramme
axes[0].hist(df["poids_kg"], bins=6, color="steelblue", edgecolor="black", alpha=0.7)
axes[0].axvline(df["poids_kg"].mean(), color="red", linestyle="--", label=f"Moyenne")
axes[0].axvline(df["poids_kg"].median(), color="green", linestyle="--", label=f"Médiane")
axes[0].set_title("Distribution du poids")
axes[0].set_xlabel("Poids (kg)")
axes[0].legend()

# Boxplot
axes[1].boxplot(df["poids_kg"], vert=True)
axes[1].set_title("Boxplot du poids")
axes[1].set_ylabel("Poids (kg)")

plt.tight_layout()
plt.show()

# %%
# Comptage des modalités
print(df["ville"].value_counts())
# Out:
# ville
# Lyon         2
# Marseille    2
# Paris        2
# Bordeaux     1
# Nantes       1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 4))
df["ville"].value_counts().plot(kind="bar", ax=ax, color="coral", edgecolor="black")
ax.set_title("Répartition des villes")
ax.set_ylabel("Nombre d'observations")
ax.tick_params(axis="x", rotation=0)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
df["satisfaction"].value_counts().sort_index().plot(
    kind="bar", ax=ax, color="mediumseagreen", edgecolor="black"
)
ax.set_title("Niveau de satisfaction (ordonné)")
ax.set_ylabel("Nombre")
ax.tick_params(axis="x", rotation=0)
plt.tight_layout()
plt.show()

# %%
# Longueur des commentaires
df["long_commentaire"] = df["commentaire"].str.len()
print(df[["commentaire", "long_commentaire"]])

print(f"\nLongueur moyenne : {df['long_commentaire'].mean():.1f} caractères")
print(f"Longueur max     : {df['long_commentaire'].max()} caractères")
# Out:
#                           commentaire  long_commentaire
# 0  Super expérience, très satisfait !                34
# 1               Livraison trop longue                21
# 2      Produit parfait, rien à redire                30
# 3        Article cassé à la réception                28
# 4                                 RAS                 3
# 5             Excellente qualité prix                23
# 6              Bof, j'attendais mieux                22
# 7              Parfait, je recommande                22
#
# Longueur moyenne : 22.9 caractères
# Longueur max     : 34 caractères

# %%
print(f"Plage : du {df['date_inscription'].min().date()} au {df['date_inscription'].max().date()}")
print(f"\nPar année :")
print(df["date_inscription"].dt.year.value_counts().sort_index())
# Out:
# Plage : du 2020-11-30 au 2023-07-04
#
# Par année :
# date_inscription
# 2020    1
# 2021    2
# 2022    2
# 2023    3
# Name: count, dtype: int64

# %%
#| eval: false
# TODO: Exercice 2

# %%
# 1. taille_m
print("=== taille_m ===")
print(f"Moyenne  : {df['taille_m'].mean():.3f}")
print(f"Médiane  : {df['taille_m'].median():.3f}")
print(f"Écart-t. : {df['taille_m'].std():.3f}")

fig, ax = plt.subplots(figsize=(8, 3))
ax.hist(df["taille_m"], bins=6, color="steelblue", edgecolor="black", alpha=0.7)
ax.axvline(df["taille_m"].mean(), color="red", linestyle="--", label="Moyenne")
ax.set_title("Distribution de la taille")
ax.set_xlabel("Taille (m)")
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# === taille_m ===
# Moyenne  : 1.750
# Médiane  : 1.750
# Écart-t. : 0.105

# %%
# 2. nb_enfants
print("=== nb_enfants ===")
print(df["nb_enfants"].value_counts().sort_index())

fig, ax = plt.subplots(figsize=(8, 3))
df["nb_enfants"].value_counts().sort_index().plot(
    kind="bar", ax=ax, color="coral", edgecolor="black"
)
ax.set_title("Nombre d'enfants")
ax.set_ylabel("Nombre")
ax.tick_params(axis="x", rotation=0)
plt.tight_layout()
plt.show()
# Out:
# === nb_enfants ===
# nb_enfants
# 0    3
# 1    2
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
# 3. niveau_etudes ordinal
ordre_etudes = CategoricalDtype(
    categories=["Bac", "Licence", "Master", "Doctorat"],
    ordered=True
)
df["niveau_etudes"] = df["niveau_etudes"].astype(ordre_etudes)

print("Ordre :", df["niveau_etudes"].cat.categories.tolist())

fig, ax = plt.subplots(figsize=(8, 3))
df["niveau_etudes"].value_counts().sort_index().plot(
    kind="bar", ax=ax, color="mediumseagreen", edgecolor="black"
)
ax.set_title("Répartition des niveaux d'études")
ax.tick_params(axis="x", rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Ordre : ['Bac', 'Licence', 'Master', 'Doctorat']

# %%
# 4. date_inscription
print("=== Par année ===")
print(df["date_inscription"].dt.year.value_counts().sort_index())

print("\n=== Par mois ===")
print(df["date_inscription"].dt.month.value_counts().sort_index())
# Out:
# === Par année ===
# date_inscription
# 2020    1
# 2021    2
# 2022    2
# 2023    3
# Name: count, dtype: int64
#
# === Par mois ===
# date_inscription
# 1     1
# 3     1
# 5     1
# 6     1
# 7     1
# 9     1
# 11    1
# 12    1
# Name: count, dtype: int64

# %%
#| eval: false
# TODO: Exercice 3

# %%
# Reconstruire le dataset
data = {
    "id_transaction": [10001, 10002, 10003, 10004, 10005],
    "montant": [125.50, 89.99, 450.00, 45.30, 199.90],
    "categorie_age": ["18-25", "26-35", "36-50", "26-35", "51+"],
    "note_etoiles": [4, 5, 3, 5, 4],
    "code_iata": ["CDG", "LAX", "CDG", "JFK", "CDG"],
    "date_achat": ["2024-01-15", "2024-02-20", "2024-03-10", "2024-01-22", "2024-04-05"],
    "est_premium": [1, 0, 1, 1, 0]
}
df_test = pd.DataFrame(data)

# 1. Dtypes par défaut
print("=== Dtypes par défaut ===")
print(df_test.dtypes)
# Out:
# === Dtypes par défaut ===
# id_transaction      int64
# montant           float64
# categorie_age         str
# note_etoiles        int64
# code_iata             str
# date_achat            str
# est_premium         int64
# dtype: object

# %%
# 3. Corrections

# id_transaction → string
df_test["id_transaction"] = df_test["id_transaction"].astype(str)

# categorie_age → ordinale
ordre_age = CategoricalDtype(
    categories=["18-25", "26-35", "36-50", "51+"],
    ordered=True
)
df_test["categorie_age"] = df_test["categorie_age"].astype(ordre_age)

# date_achat → datetime
df_test["date_achat"] = pd.to_datetime(df_test["date_achat"])

# est_premium → category (nominale binaire)
df_test["est_premium"] = df_test["est_premium"].astype("category")

# code_iata → category (nominale)
df_test["code_iata"] = df_test["code_iata"].astype("category")

print("=== Dtypes corrigés ===")
print(df_test.dtypes)
# Out:
# === Dtypes corrigés ===
# id_transaction               str
# montant                  float64
# categorie_age           category
# note_etoiles               int64
# code_iata               category
# date_achat        datetime64[us]
# est_premium             category
# dtype: object

# %%
# 4. Vérifier describe
print("=== describe() ===")
print(df_test.describe())
# Out:
# === describe() ===
#           montant  note_etoiles           date_achat
# count    5.000000       5.00000                    5
# mean   182.138000       4.20000  2024-02-19 19:12:00
# min     45.300000       3.00000  2024-01-15 00:00:00
# 25%     89.990000       4.00000  2024-01-22 00:00:00
# 50%    125.500000       4.00000  2024-02-20 00:00:00
# 75%    199.900000       5.00000  2024-03-10 00:00:00
# max    450.000000       5.00000  2024-04-05 00:00:00
# std    160.069746       0.83666                  NaN

# %%
#| eval: false
df_ventes = pd.read_csv("ressources_tp/ventes_ecommerce.csv", parse_dates=["date"])

# %%
#| eval: false
# TODO: Exercice bilan

# %%
# Chargement
df_ventes = pd.read_csv("ressources_tp/ventes_ecommerce.csv", parse_dates=["date"])

# 1. Audit typologique
print("=== Audit typologique ===\n")

audit = pd.DataFrame({
    "colonne": df_ventes.columns,
    "dtype_actuel": df_ventes.dtypes.values
})
print(audit)
# Out:
# === Audit typologique ===
#
#            colonne    dtype_actuel
# 0   id_transaction             str
# 1             date  datetime64[us]
# 2        id_client             str
# 3       id_produit             str
# 4      nom_produit             str
# 5        categorie             str
# 6         quantite           int64
# 7    prix_unitaire         float64
# 8    montant_total         float64
# 9           region             str
# 10   mode_paiement             str
# 11          statut             str

# %%
# 2. Conversions
for col in ["nom_produit", "categorie", "region", "mode_paiement", "statut"]:
    df_ventes[col] = df_ventes[col].astype("category")

# 3. Vérification
print(df_ventes.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2003 entries, 0 to 2002
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_transaction  2003 non-null   str
#  1   date            2003 non-null   datetime64[us]
#  2   id_client       2003 non-null   str
#  3   id_produit      2003 non-null   str
#  4   nom_produit     2003 non-null   category
#  5   categorie       2003 non-null   category
#  6   quantite        2003 non-null   int64
#  7   prix_unitaire   2003 non-null   float64
#  8   montant_total   2003 non-null   float64
#  9   region          1943 non-null   category
#  10  mode_paiement   1963 non-null   category
#  11  statut          2003 non-null   category
# dtypes: category(5), datetime64[us](1), float64(2), int64(1), str(3)
# memory usage: 119.8 KB
# None

# %%
# 4. Graphiques adaptés
fig, axes = plt.subplots(2, 2, figsize=(15, 8))

# Quantitative continue : montant_total
axes[0, 0].hist(df_ventes["montant_total"], bins=40, color="steelblue", 
                edgecolor="black", alpha=0.7)
axes[0, 0].set_title("Histogramme : montant_total (quanti continue)")
axes[0, 0].set_xlabel("Montant (€)")

# Qualitative nominale : categorie
df_ventes["categorie"].value_counts().plot(
    kind="bar", ax=axes[0, 1], color="coral", edgecolor="black"
)
axes[0, 1].set_title("Bar chart : categorie (quali nominale)")
axes[0, 1].tick_params(axis="x", rotation=45)

# Qualitative nominale ordonnée (on traite statut comme nominal ici)
df_ventes["statut"].value_counts().plot(
    kind="bar", ax=axes[1, 0], color="mediumseagreen", edgecolor="black"
)
axes[1, 0].set_title("Bar chart : statut (quali nominale)")
axes[1, 0].tick_params(axis="x", rotation=45)

# Temporelle : évolution mensuelle
ca_mensuel = df_ventes.groupby(df_ventes["date"].dt.to_period("M"))["montant_total"].sum()
axes[1, 1].plot(ca_mensuel.index.astype(str), ca_mensuel.values, 
                marker="o", color="purple")
axes[1, 1].set_title("Line plot : CA mensuel (temporelle)")
axes[1, 1].tick_params(axis="x", rotation=45)

for ax in axes.flat:
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
taille_avant = pd.read_csv("ressources_tp/ventes_ecommerce.csv", parse_dates=["date"]).memory_usage(deep=True).sum()
taille_apres = df_ventes.memory_usage(deep=True).sum()

print(f"Mémoire avant : {taille_avant / 1024:.1f} KB")
print(f"Mémoire après : {taille_apres / 1024:.1f} KB")
print(f"Réduction    : {(1 - taille_apres/taille_avant)*100:.1f}%")
# Out:
# Mémoire avant : 1028.3 KB
# Mémoire après : 392.7 KB
# Réduction    : 61.8%
